# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("Police_Department_Incident_Reports__2018_to_Present (2).csv")

# %%
df2 = df.corr()

# %%
df2
# Out:
#                                                     Incident Year    Row ID  \
# Incident Year                                            1.000000  0.894119
# Row ID                                                   0.894119  1.000000
# Incident ID                                              0.894119  1.000000
# Incident Number                                          0.568575  0.573559
# CAD Number                                               0.164404  0.206750
# Incident Code                                           -0.026346 -0.025916
# CNN                                                     -0.030671 -0.019459
# Supervisor District                                      0.026120  0.018423
# Latitude                                                -0.027324 -0.029644
# Longitude                                               -0.004777 -0.012245
# SF Find Neighborhoods                                    0.024546  0.018935
# ...

# %%
df.drop(['Row ID' , 'Incident ID' , 'Incident Number' , 'CAD Number' , 'Report Type Code' , 'Filed Online' ,'Incident Code' , 'Incident Subcategory' ,'CNN','Supervisor District' , 'point' ,'SF Find Neighborhoods',
        'Current Police Districts' , 'Current Supervisor Districts' , 'Analysis Neighborhoods' , 'HSOC Zones as of 2018-06-05' , 'OWED Public Spaces' , 'Central Market/Tenderloin Boundary Polygon - Updated' , 
        'Parks Alliance CPSI (27+TL sites)' , 'ESNCAG - Boundary File' , 'Areas of Vulnerability, 2016'] , axis = 1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28799 entries, 0 to 28798
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Incident Datetime        28799 non-null  object
#  1   Incident Date            28799 non-null  object
#  2   Incident Time            28799 non-null  object
#  3   Incident Year            28799 non-null  int64
#  4   Incident Day of Week     28799 non-null  object
#  5   Report Datetime          28799 non-null  object
#  6   Report Type Description  28799 non-null  object
#  7   Incident Category        28749 non-null  object
#  8   Incident Description     28799 non-null  object
#  9   Resolution               28799 non-null  object
#  10  Intersection             26911 non-null  object
#  11  Police District          28798 non-null  object
#  12  Analysis Neighborhood    26903 non-null  object
#  13  Latitude                 26910 non-null  float64
# ...

# %%
DF_Category = pd.DataFrame(df['Incident Category'].value_counts())

DF_Category = DF_Category.reset_index().rename(columns={'index':'Incident Category' ,'Incident Category' : ' total'})

DF_Category.head(16)
# Out:
#                            Incident Category   total
# 0                              Larceny Theft    8071
# 1                        Other Miscellaneous    2253
# 2                         Malicious Mischief    1927
# 3                                    Assault    1756
# 4                               Non-Criminal    1727
# 5                                   Burglary    1624
# 6                        Motor Vehicle Theft    1333
# 7                          Recovered Vehicle    1099
# 8                                    Warrant     974
# 9                              Lost Property     901
# 10                                     Fraud     772
# 11                              Drug Offense     768
# 12                                   Robbery     741
# 13                            Missing Person     637
# 14  Offences Against The Family And Children     632
# 15                            Suspicious Occ     542

# %%
DF_Category.sort_values([' total'],ascending=False, axis=0, inplace=True)

DF_Category
# Out:
#                              Incident Category   total
# 0                                Larceny Theft    8071
# 1                          Other Miscellaneous    2253
# 2                           Malicious Mischief    1927
# 3                                      Assault    1756
# 4                                 Non-Criminal    1727
# 5                                     Burglary    1624
# 6                          Motor Vehicle Theft    1333
# 7                            Recovered Vehicle    1099
# 8                                      Warrant     974
# 9                                Lost Property     901
# 10                                       Fraud     772
# 11                                Drug Offense     768
# 12                                     Robbery     741
# 13                              Missing Person     637
# 14    Offences Against The Family And Children     632
# 15                              Suspicious Occ     542
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DF_Category_top5 =DF_Category.head(5)





DF_Category_top5 

ax = plt.subplots(figsize=(10, 9))
sns.set(style="whitegrid")
ax = sns.barplot(x="Incident Category", y=" total", data=DF_Category_top5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import preprocessing

# %%
# x = df[['Incident Time', 'Incident Year' ,'Incident Day of Week'  , 'Report Type Description' , 'Incident Category' , 'Incident Description' , 'Resolution'  ,'Intersection' ,'Police District']]

# %%
#class_le=LabelEncoder()
#t=class_le.fit_transform(y)
#X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=4)
#print ('Train set:', X_train.shape,  y_train.shape)
#print ('Test set:', X_test.shape,  y_test.shape)

# %%
from sklearn.svm import SVC
from sklearn import svm

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

#loanTree = DecisionTreeClassifier(criterion="entropy", max_depth = 1)

#loanTree

# %%
ax = plt.subplots(figsize=(10, 9))
ax = sns.scatterplot(x="Incident Category", y=" total", data=DF_Category_top5)

# %%
df = df.dropna(axis =0 )

# %%
df2 = df[['Incident Date','Incident Time','Incident Year' ,'Report Type Description' , 'Incident Category' , 'Incident Description' , 'Analysis Neighborhood']]

# %%
df2
# Out:
#       Incident Date Incident Time  Incident Year Report Type Description  \
# 0        2019/05/01         01:00           2019                 Initial
# 1        2019/06/22         07:45           2019                 Initial
# 2        2019/06/03         16:16           2019      Initial Supplement
# 3        2018/11/16         16:34           2018      Initial Supplement
# 4        2019/05/27         02:25           2019                 Initial
# ...             ...           ...            ...                     ...
# 28793    2020/03/31         13:20           2020                 Initial
# 28794    2020/03/30         11:43           2020      Initial Supplement
# 28795    2020/03/30         21:25           2020                 Initial
# 28796    2020/03/15         17:48           2020                 Initial
# 28797    2020/03/29         22:00           2020        Coplogic Initial
#
#                               Incident Category  \
# ...

# %%
X= df2[['Report Type Description' , 'Incident Category' , 'Incident Description' , ]]

# %%
y=df2[['Analysis Neighborhood']]

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26853 entries, 0 to 28797
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Report Type Description  26853 non-null  object
#  1   Incident Category        26853 non-null  object
#  2   Incident Description     26853 non-null  object
# dtypes: object(3)
# memory usage: 839.2+ KB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26853 entries, 0 to 28797
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Analysis Neighborhood  26853 non-null  object
# dtypes: object(1)
# memory usage: 419.6+ KB

# %%
le = preprocessing.LabelEncoder()

le.fit(X['Report Type Description'])

X['Report Type Description'] = le.transform(X['Report Type Description'])
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26853 entries, 0 to 28797
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Report Type Description  26853 non-null  int64
#  1   Incident Category        26853 non-null  object
#  2   Incident Description     26853 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 839.2+ KB

# %%
le = preprocessing.LabelEncoder()

le.fit(X['Incident Category'])

X['Incident Category'] = le.transform(X['Incident Category'])
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
le = preprocessing.LabelEncoder()

le.fit(X['Incident Description'])

X['Incident Description'] = le.transform(X['Incident Description'])
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26853 entries, 0 to 28797
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Report Type Description  26853 non-null  int64
#  1   Incident Category        26853 non-null  int64
#  2   Incident Description     26853 non-null  int64
# dtypes: int64(3)
# memory usage: 839.2 KB

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.5, random_state=3)

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 10)
drugTree # it shows the default parameters
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predTree = drugTree.predict(X_testset)

# %%
print (predTree [0:5])
print (y_testset [0:5])
# Out:
# ['Mission' 'Tenderloin' 'Mission' 'Mission' 'Mission']
#                 Analysis Neighborhood
# 2280              Castro/Upper Market
# 15244                        Nob Hill
# 18705                     Mission Bay
# 6116   Financial District/South Beach
# 17406                  Haight Ashbury

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.15021970656140612

# %%
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)

# %%
X
# Out:
# array([[-0.00199874,  0.55153205, -1.00450115],
#        [-0.00199874,  0.46603957, -0.21113765],
#        [ 0.90769795,  0.20956212, -0.5954231 ],
#        ...,
#        [-0.00199874, -1.75676498, -1.7792702 ],
#        [-0.00199874,  1.06448695,  1.17724848],
#        [-1.82139212, -0.21790029,  0.86114271]])

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (21482, 3) (21482, 1)
# Test set: (5371, 3) (5371, 1)

# %%
k = 9
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#            weights='uniform')

# %%
yhat = neigh.predict(X_test)
yhat[0:5]
# Out:
# array(['Mission', 'Financial District/South Beach',
#        'Bayview Hunters Point', 'Castro/Upper Market', 'Tenderloin'],
#       dtype=object)

# %%
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", )
# Out:
# Train set Accuracy:  0.14463271576203332
# Test set Accuracy:

# %%
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)

# %%
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhatsvm))
